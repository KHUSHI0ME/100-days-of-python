# %% [markdown]
# <a href="https://colab.research.google.com/github/KHUSHI0ME/100-days-of-python/blob/main/Python_2_0_DAY%208.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **FINALLY KEYWORDS/CLAUSE**

# %% [markdown]
# **Finally Clause**
#
# The finally code block is also a part of exception handling. When we handle exception using the try and except block, we can include a finally block at the end. The finally block is always executed, so it is generally used for doing the concluding tasks like closing file resources or closing database connection or may be ending the program execution with a delightful message.
#
#
# ```
# # Syntax:
# try:
#    #statements which could generate
#    #exception
# except:
#    #solution of generated exception
# finally:
#     #block of code which is going to
#     #execute in any situation
# ```
#
#
#
#
# The finally block is executed irrespective of the outcome of try……except…..else blocks
# One of the important use cases of finally block is in a function which returns a value.

# %%
try:
  l = [1,2,3,4]
  i = int(input("Enter the index:"))
  print(l[i])
except:
  print("Some error occured:")

finally:
  print("This will always execute:")
# Out:
# Enter the index:1
# 2
# This will always execute:

# %%
try:
  l = [1,2,3,4]
  i = int(input("Enter the index:"))
  print(l[i])
except:
  print("Some error occured:")

# finally:
#   print("This will always execute:")

print("I am always executed")
# Out:
# Enter the index:dd
# Some error occured:
# I am always executed

# %%
def func1():
  try:
    l = [1,5,6,7,8]
    i = int(input("Enter the index:"))
    print(l[i])
    return 1
  except:
    print("Some error occured:")
    return 0

  # finally:
  #   print("This will always execute:")
  print("I am always executed")

print(func1())
# Out:
# Enter the index:3
# 7
# 1

# %%
def func1():
  try:
    l = [1,5,6,7,8]
    i = int(input("Enter the index:"))
    print(l[i])
    return 1
  except:
    print("Some error occured:")
    return 0

  # finally:
  #   print("This will always execute:")
  print("I am always executed")

print(func1())
# Out:
# Enter the index:dd
# Some error occured:
# 0

# %%
def func1():
  try:
    l = [1,5,6,7,8]
    i = int(input("Enter the index:"))
    print(l[i])
    return 1
  except:
    print("Some error occured:")
    return 0

  finally:
    print("This will always execute:")


print(func1())
# Out:
# Enter the index:4
# 8
# This will always execute:
# 1

# %% [markdown]
# # **CUSTOM ERROR**

# %% [markdown]
# **Raising Custom errors**
#
# In python, we can raise custom errors by using the raise keyword.
#
#
#
# ```
# salary = int(input("Enter salary amount: "))
# if not 2000 < salary < 5000:
#     raise ValueError("Not a valid salary")
# ```
#
# Defining Custom Exceptions
# In Python, we can define custom exceptions by creating a new class that is derived from the built-in Exception class.
#
# Here's the syntax to define custom exceptions:
#
# ```
# class CustomError(Exception):
#   # code ...
#   pass
#
# try:
#   # code ...
#
# except CustomError:
#   # code...
# ```

# %%
a = int(input("Enter the value between 5 and 9:"))
if(a<5 or a>9):
  raise ValueError("Not a valid value")
# Out:
# Enter the value between 5 and 9:10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1778/3367176060.py in <cell line: 0>()
#       1 a = int(input("Enter the value between 5 and 9:"))
#       2 if(a<5 or a>9):
# ----> 3   raise ValueError("Not a valid value")
#
# ValueError: Not a valid value

# %%
a = int(input("Enter the value between 5 and 9:"))
if(a<5 or a>9):
  raise ValueError("Not a valid value")
# Out:
# Enter the value between 5 and 9:8

# %%
name = input("Enter a name that starts with k: ")

if not name.lower().startswith('k'):
    raise NameError("Not a valid name")

print("Valid name")
# Out:
# Enter a name that starts with k: khushi
# Valid name

# %%
salary = int(input("Enter salary amount: "))
if not 2000 < salary < 5000:
    raise ValueError("Not a valid salary")
# Out:
# Enter salary amount: 1000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1778/700348630.py in <cell line: 0>()
#       1 salary = int(input("Enter salary amount: "))
#       2 if not 2000 < salary < 5000:
# ----> 3     raise ValueError("Not a valid salary")
#
# ValueError: Not a valid salary

# %%
salary = int(input("Enter salary amount: "))
if not 2000 < salary < 5000:
    raise ValueError("Not a valid salary")
# Out:
# Enter salary amount: 3000

# %%
a = int(input("Enter the value between 5 and 9:"))
if(a<5 or a>9):
  raise ValueError("Not a valid value")

print("quit")
# Out:
# Enter the value between 5 and 9:6
# quit

# %% [markdown]
# # **EXERCISE - SECRET CODE LANGUAGE**

# %% [markdown]
# WRITE A PYTHON PROGRAM TO TRANSLATE A MESSAGE INTO SECRET CODE LANGUAGE.

# %%
print("WELCOME TO SECRET CODE LANGUAGE")

message = input("Enter a message: ")

# Coding
if len(message) >= 3:
    coded = message[1:] + message[0]
    print("Coded Message:", coded)

# For short messages
else:
    coded = message[::-1]
    print("Coded Message:", coded)

# Decoding
if len(message) >= 3:
    decoded = coded[-1] + coded[:-1]
    print("Decoded Message:", decoded)
else:
    decoded = coded[::-1]
    print("Decoded Message:", decoded)
# Out:
# WELCOME TO SECRET CODE LANGUAGE
# Enter a message: BUBZEE
# Coded Message: UBZEEB
# Decoded Message: BUBZEE

# %%
print("WELCOME TO SECRET CODE LANGUAGE")

message = input("Enter a message: ")

# Coding
if len(message) >= 3:
    coded = message[1:] + message[0]
    print("Coded Message:", coded)

# For short messages
else:
    coded = message[::-1]
    print("Coded Message:", coded)

# Decoding
if len(message) >= 3:
    decoded = coded[-1] + coded[:-1]
    print("Decoded Message:", decoded)
else:
    decoded = coded[::-1]
    print("Decoded Message:", decoded)
# Out:
# WELCOME TO SECRET CODE LANGUAGE
# Enter a message: HI
# Coded Message: IH
# Decoded Message: HI
